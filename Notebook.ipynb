# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the data

# %%
df = pd.read_csv("/Users/iquranaseem/Desktop/Project/hotel_bookings.csv")

# %% [markdown]
# # Explatory Data Analysis and Data Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(full_df['reservation_status_date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['reservation_status_date'] = pd.to_datetime(full_df['reservation_status_date'])
#
# NameError: name 'full_df' is not defined

# %%
df['reservation_status_date']
# Out:
# 0         2015-07-01
# 1         2015-07-01
# 2         2015-07-02
# 3         2015-07-02
# 4         2015-07-03
#              ...
# 119385    2017-09-06
# 119386    2017-09-07
# 119387    2017-09-07
# 119388    2017-09-07
# 119389    2017-09-07
# Name: reservation_status_date, Length: 119390, dtype: object

# %%
df.describe(include = object)
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
for col in full_df.describe(include='object').columns:
    print(col)
    print(full_df[col].unique())
    print("-" * 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for col in full_df.describe(include='object').columns:
#       2     print(col)
#       3     print(full_df[col].unique())
#
# NameError: name 'full_df' is not defined

# %% [markdown]
# # Looking for missing values in dataframe

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company', 'agent'], axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
import matplotlib.pyplot as plt

plt.figure()
df["adr"].plot(kind="box")
plt.show()

plt.figure()
df["days_in_waiting_list"].plot(kind="box")
plt.show()

plt.figure()
df["adults"].plot(kind="box")
plt.show()

plt.figure()
df["children"].plot(kind="box")
plt.show()

plt.figure()
df["babies"].plot(kind="box")
plt.show()

plt.figure()
df["lead_time"].plot(kind="box")
plt.show()

plt.figure()
df["stays_in_weekend_nights"].plot(kind="box")
plt.show()

plt.figure()
df["stays_in_week_nights"].plot(kind="box")
plt.show()

# %%
df = df[df["adr"]<5000]
df = df[df["days_in_waiting_list"]<350]
df = df[df["adults"]<9]
df = df[df["children"]<5]
df = df[df["lead_time"]<650]
df = df[df["stays_in_weekend_nights"]<10]
df = df[df["stays_in_week_nights"]<29]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118801.000000  118801.000000      118801.000000
# mean        0.371041     104.099915        2016.157819
# std         0.483085     106.604877           0.707559
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     629.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118801.000000              118801.000000
# mean                  27.160950                  15.800414
# std                   13.588055                   8.780902
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analysis and Visualisations

# %%
plt.figure(figsize=(5, 4))
plt.title('Reservation status count')
plt.bar(['Not cancelled', 'Cancelled'], df['is_canceled'].value_counts(), edgecolor='k', width=0.7)
plt.show()

# %% [markdown]
# The bar graph illustrates the percentage of reservations that are either cancelled or not cancelled. It is evident that a significant majority of reservations have not been cancelled. However, it is noteworthy that 37% of clients have cancelled their reservations, which has a considerable impact on hotel profits. This high cancellation rate suggests potential issues that may need addressing to improve overall occupancy and revenue stability.

# %%
# Plotting
plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='coolwarm')


legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1), labels=['Not cancelled', 'Cancelled'])

plt.title('Reservations status in different hotels', size=20)
plt.xlabel('Hotel')
plt.ylabel('Number of reservations')
plt.show()

# %% [markdown]
# In comparison to resort hotels, city hotels have more bookings. It's possible that resort hotels are more expensive than those in cities.

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.720442
# 1    0.279558
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.583278
# 1    0.416722
# Name: is_canceled, dtype: float64

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20, 8))
plt.title('Average Daily Rate in City and Resort Hotel', size=30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.xlabel('Index')
plt.ylabel('Average Daily Rate')
plt.legend()  # Ensure the legend is displayed
plt.show()

# %% [markdown]
# The line graph above shows that, on certain daily rate for a city hotel is less than that of a resort hotel, and on other days, it is even less. It goes without saying the weekends and holidays may see a rise in resort hotel rates.

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16, 8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='dark')

# Correcting the legend handling
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1), labels=['Not cancelled', 'Cancelled'])

plt.title('Reservation Status by Month', fontsize=20)
plt.xlabel('Month')
plt.ylabel('Number of Reservations')
plt.show()

# %% [markdown]
# We have developed the group bar graph to analyse the months with the highest and lowest reservations levels according to reservation status. As can be seen, both the numbers of confirmed reservations and the number of cancelled reservations are largest in August, whereas January is the month with the most cancelled reservations.

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per month', fontsize = 30)
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %% [markdown]
# This  bar graph demostrats the cancellations are most common when prices are greatest and are least common when thye are lowest. Therefore, the cost of accomodation is solely responsible for the cancellations.
#
# Now, let's see which country has the highest reservations cancelled. The top country is Portugal wuth the highest number of cancellations.

# %%
cancelled_df = df[df['is_canceled'] ==1]
top_10_places = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize = (8,8))
plt.title("Top ten countries with reservations cancelled")
plt.pie(top_10_places, autopct = '%.2f', labels = top_10_places.index)
plt.show()

# %% [markdown]
# Around fourty six percent of clients come from online travel agencies, and twenty seven come from groups. Only four percent of client book hotels by visiting them and making reservations.

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56395
# Offline TA/TO    24144
# Groups           19745
# Direct           12436
# Corporate         5110
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474701
# Offline TA/TO    0.203231
# Groups           0.166202
# Direct           0.104679
# Corporate        0.043013
# Complementary    0.006178
# Aviation         0.001995
# Name: market_segment, dtype: float64

# %%
cancelled_df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.470417
# Groups           0.273208
# Offline TA/TO    0.187591
# Direct           0.043376
# Corporate        0.022187
# Complementary    0.002042
# Aviation         0.001180
# Name: market_segment, dtype: float64

# %%
# Calculate the mean ADR for cancelled reservations
cancelled_df_adr = cancelled_df.groupby('reservation_status_date')['adr'].mean().reset_index()
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Filter out non-cancelled reservations and calculate the mean ADR
non_cancelled_df = df[df['is_canceled'] == 0]
non_cancelled_df_adr = non_cancelled_df.groupby('reservation_status_date')['adr'].mean().reset_index()
non_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Plotting the ADR for both cancelled and non-cancelled reservations
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate')
plt.plot(non_cancelled_df_adr['reservation_status_date'], non_cancelled_df_adr['adr'], label='non cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate')
plt.legend()
plt.show()

# %% [markdown]
# As seen in the graph, reservations are cancelled when the avergae daily rate is higher than when it is not cancelled. It clearned prives all the above analysis, that the higher price leaders to higher cancelled.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `cancelled_df` and `df` are your DataFrames

# Calculate the mean ADR for cancelled reservations
cancelled_df_adr = cancelled_df.groupby('reservation_status_date')['adr'].mean().reset_index()
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Filter out non-cancelled reservations and calculate the mean ADR
non_cancelled_df = df[df['is_canceled'] == 0]
non_cancelled_df_adr = non_cancelled_df.groupby('reservation_status_date')['adr'].mean().reset_index()
non_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Convert 'reservation_status_date' to datetime
cancelled_df_adr['reservation_status_date'] = pd.to_datetime(cancelled_df_adr['reservation_status_date'])
non_cancelled_df_adr['reservation_status_date'] = pd.to_datetime(non_cancelled_df_adr['reservation_status_date'])

# Filter data to include only from 2016 onwards
cancelled_df_adr = cancelled_df_adr[cancelled_df_adr['reservation_status_date'] >= '2016-01-01']
non_cancelled_df_adr = non_cancelled_df_adr[non_cancelled_df_adr['reservation_status_date'] >= '2016-01-01']

# Plotting the ADR for both cancelled and non-cancelled reservations
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate', fontsize = 30)
plt.plot(non_cancelled_df_adr['reservation_status_date'], non_cancelled_df_adr['adr'], label='non cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate')
plt.legend(fontsize = 20)
plt.show()
